# %% [markdown]
# <a href="https://colab.research.google.com/github/Claus2001/COMP-593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-20de3543-395d-4b34-9b3e-4a32454ac6d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20de3543-395d-4b34-9b3e-4a32454ac6d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
# Confirm the table was added to the DB as expected
myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('relationships')")
print(myCursor.fetchone())
myConnection.close()
# Out:
# ('id, user_id, friend_id',)

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),                          
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                      );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT + FROM relationships 
                  LIMIT 20;"""

myCursor.execute(selectStatement)
results = myCursor.fetchall()
pprint(results)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-3ff624406672> in <module>()
#      10                   LIMIT 20;"""
#      11
# ---> 12 myCursor.execute(selectStatement)
#      13 results = myCursor.fetchall()
#      14 pprint(results)
#
# OperationalError: near "FROM": syntax error

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

myConnection = sqlite3.connect('social_network.db')

myCursor = myConnection.cursor()

#Complete the below query
addRelationshipsQuery = """INSERT INTO relationships (user_id, friend_id)
                           VALUES (?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  args = (randrange(1, 1001), randrange(1, 1001))
  #Execute the query
  myCursor.execute(addRelationshipsQuery, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint

myConnection = sqlite3.connect('social_network.db')
myCursor = myConnection.cursor()

#Complete the below query
query =  """SELECT people.name, COUNT(relationships.friend_id) FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)
myConnection.close()


#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
#fp = open('report.txt', mode='')

#for result in results:
  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# [('Colleen Kirby', 1),
#  ('Donna Hernandez', 1),
#  ('Henry Campos', 1),
#  ('Sarah Jacobs', 1),
#  ('Carrie Smith', 2),
#  ('Jeremy Hudson', 1),
#  ('Theresa Chandler', 1),
#  ('Danielle Fox', 3),
#  ('Cynthia Lyons', 1),
#  ('Eric Berger', 1),
#  ('David Simmons', 2),
#  ('Rodney Brady', 1),
#  ('Keith Gallegos', 1),
#  ('Monique Mitchell', 1),
#  ('Samantha Jordan', 2),
#  ('Andrea Montoya', 1),
#  ('Amanda Carter', 2),
#  ('John Lester', 2),
#  ('Joshua Ramsey', 1),
#  ('Matthew Figueroa', 2),
#  ('Michael Atkinson', 1),
#  ('Ethan White', 2),
#  ('Anthony Taylor', 2),
#  ('Scott Tapia', 1),
#  ('Jerry Salazar', 1),
#  ('Mark Jones', 1),
#  ('Carrie Pierce', 2),
#  ('Crystal Golden', 1),
#  ('William Gallegos', 2),
#  ('Mathew Galloway', 2),
#  ('Kevin White', 1),
#  ('Nicole Howard', 1),
#  ('Troy Mills', 1),
#  ('Jason Young', 1),
#  ('Christina Perry', 1),
#  ('Erica Conway', 1),
#  ('Nancy Brown', 2),
#  ('Lindsey Lopez', 1),
#  ('Robert Tucker', 1),
#  ('Katrina Cummings', 2),
#  ('Steven Patel', 1),
#  ('Timothy Taylor', 1),
#  ('Courtney Williams', 1),
#  ('Kari Ford', 2),
#  ('Brittany Roman', 1),
#  ('Bill Ellis', 1),
#  ('Laura Ryan', 1),
#  ('Alan Lang', 2),
#  ('Pamela Hall', 2),
#  ('Alicia Williams', 1),
#  ('Nicolas Thomas', 1),
#  ('Margaret Lutz', 1),
#  ('Carol Hurst', 2),
#  ('Michelle Johnson', 3),
#  ('Kevin Clark', 1),
#  ('Alison Harris', 1),
#  ('Loretta Zuniga', 2),
#  ('Isaac Jones', 2),
#  ('Melanie Moreno', 3),
#  ('Jeremiah Davis', 1),
#  ('Michelle Hayes', 2),
#  ('Kathleen Buck', 1),
#  ('William Matthews', 3),
#  ('Jade Gonzalez', 1),
#  ('Sarah Nicholson', 1),
#  ('Cheryl Gibson', 3),
#  ('Chad Smith', 2),
#  ('Jessica Soto', 1),
#  ('Derek Beltran', 1),
#  ('Eric Mcpherson', 2),
#  ('Jordan Russell', 1),
#  ('Amy Hernandez', 1),
#  ('Joshua Estrada', 1),
#  ('Christopher Miller', 2),
#  ('Jennifer Reyes', 2),
#  ('Joel Washington', 1),
#  ('Carol Bennett', 1),
#  ('Mr. George Velasquez DDS', 2),
#  ('William Carlson', 1),
#  ('Julie Aguilar', 1),
#  ('Michael Holloway', 1),
#  ('Laura Brown', 1),
#  ('Mark Gallegos', 1),
#  ('Valerie Wagner', 4),
#  ('Michael Aguilar', 1),
#  ('John Young', 1),
#  ('Grace Garcia', 4),
#  ('Andrew Parker', 1),
#  ('Amanda Hunt', 1),
#  ('Kenneth Smith', 1),
#  ('Donna Lopez', 1),
#  ('Maxwell Johnson', 2),
#  ('Connor Wilson', 1),
#  ('Mary Lopez', 2),
#  ('Erik Hickman', 1),
#  ('April White', 1),
#  ('Joshua Cooper', 1),
#  ('James Roberts', 5),
#  ('Andrew Case', 1),
#  ('Antonio Cook', 1),
#  ('Maria Flores', 3),
#  ('Micheal Flores', 3),
#  ('Dennis Arroyo', 1),
#  ('Shelley Robbins', 1),
#  ('Sheila Hill', 3),
#  ('Marissa Cunningham', 1),
#  ('Robert Brown', 1),
#  ('Dana Barker', 1),
#  ('Stacy Porter', 1),
#  ('Elizabeth Terry', 4),
#  ('Helen Jenkins', 1),
#  ('Brandon Gilbert', 2),
#  ('Jeremiah Vasquez', 1),
#  ('Christine Barron', 1),
#  ('Autumn Sullivan', 1),
#  ('Antonio Proctor', 1),
#  ('Terri Martinez', 1),
#  ('Beverly Young', 4),
#  ('Stacey Coleman', 1),
#  ('Annette Martinez', 2),
#  ('Brandon Cruz', 1),
#  ('Tanner Jackson', 4),
#  ('Jennifer Lopez', 1),
#  ('Bernard Thompson MD', 1),
#  ('Madeline Smith', 2),
#  ('James James', 1),
#  ('Dana Garcia', 1),
#  ('Katherine Carson', 2),
#  ('Jonathan Garner', 2),
#  ('Samantha Henderson', 1),
#  ('Paul Hill', 1),
#  ('Matthew Ramsey', 1),
#  ('Timothy Rogers', 1),
#  ('Heather Ward', 2),
#  ('John Pacheco', 2),
#  ('Peggy Ward', 2),
#  ('Jessica Mccoy', 2),
#  ('Heather Oconnor', 1),
#  ('Amanda Davies', 3),
#  ('Sarah Frank', 1),
#  ('William Morales', 1),
#  ('Bradley Williams', 1),
#  ('Larry Walls', 2),
#  ('Jessica Todd', 1),
#  ('Robert Hill', 1),
#  ('Zachary Page', 1),
#  ('Douglas Calhoun', 2),
#  ('Patricia Jones', 2),
#  ('Matthew Webb', 1),
#  ('Matthew Silva', 2),
#  ('Robert Gonzalez', 1),
#  ('Nicole Stephenson', 1),
#  ('Mrs. Yesenia Hodge', 2),
#  ('Amy Franco', 1),
#  ('Kristin Harrison', 1),
#  ('Brian Chandler', 2),
#  ('Timothy Werner', 2),
#  ('Lee Jimenez', 2),
#  ('Laurie Taylor', 4),
#  ('Daniel Arnold', 1),
#  ('Gina Peterson', 2),
#  ('Mathew Rodriguez', 1),
#  ('Ian Davis', 2),
#  ('Christopher Williams', 1),
#  ('Dennis Reeves', 1),
#  ('Adrian Browning', 2),
#  ('Robert Cruz', 2),
#  ('Jennifer Allen', 1),
#  ('Kara Duffy', 2),
#  ('Christian Newton', 1),
#  ('Tara Williams', 3),
#  ('Bradley Black', 3),
#  ('Kimberly Barnes', 1),
#  ('Michael Foster', 1),
#  ('Gail Golden', 1),
#  ('Shelley Baker', 1),
#  ('Robert Washington', 1),
#  ('Ruben Calderon', 3),
#  ('Stephen Gray', 1),
#  ('Kristen Simpson', 1),
#  ('Joseph Nelson', 2),
#  ('Jennifer Alvarado', 3),
#  ('Joseph Lawson', 1),
#  ('David Johnson', 1),
#  ('Christian West', 3),
#  ('John Mueller', 1),
#  ('Cindy Rhodes', 1),
#  ('Timothy Owens', 1),
#  ('Lori Smith', 1),
#  ('Jeremy Bruce', 1),
#  ('Kevin Herman', 1),
#  ('Carmen Walker', 1),
#  ('Jennifer Rasmussen', 1),
#  ('Kirk Wilson', 4),
#  ('John Davis', 1),
#  ('Christina Santiago', 1),
#  ('Jodi Martin', 2),
#  ('Mr. Jason Young', 2),
#  ('Margaret Taylor', 1),
#  ('Justin Schroeder', 3),
#  ('Monique Boyle', 2),
#  ('Joseph Martinez', 2),
#  ('Steven Richardson', 1),
#  ('Carl Foster', 1),
#  ('Teresa Anderson', 1),
#  ('Walter Bush', 1),
#  ('Robert Smith', 1),
#  ('Whitney Watts', 2),
#  ('Barbara Johnston', 1),
#  ('Jessica Patterson', 1),
#  ('Michael Santos', 1),
#  ('Aaron Myers', 1),
#  ('Courtney Howard', 3),
#  ('Terry Smith', 1),
#  ('Matthew Gibbs', 3),
#  ('Mary Mitchell', 1),
#  ('Joseph Castillo', 2),
#  ('Stephanie Payne', 3),
#  ('Jason Mcmillan', 1),
#  ('Jonathan Montgomery', 1),
#  ('Johnny Hunter DDS', 2),
#  ('Andrea Hall', 2),
#  ('David Smith', 1),
#  ('Stephanie Woods', 2),
#  ('Dr. Stephanie May', 1),
#  ('Casey Foster', 2),
#  ('Stephanie Owens', 1),
#  ('Gregory Nelson', 1),
#  ('Hailey Kaufman', 1),
#  ('Mark Rivera', 3),
#  ('Carla Jones', 1),
#  ('Caleb Carson', 1),
#  ('Joanna Walker', 1),
#  ('Brandy Carpenter', 2),
#  ('Patrick Reese', 2),
#  ('Lisa Thomas', 1),
#  ('Mark Campbell', 3),
#  ('Christopher Gomez', 1),
#  ('Wendy Cruz', 2),
#  ('James Carpenter', 1),
#  ('Douglas Miller', 1),
#  ('Kaitlyn Brooks', 1),
#  ('Gregory Dixon', 1),
#  ('Joshua Schroeder', 1),
#  ('Vanessa Smith', 1),
#  ('William Waller', 2),
#  ('Mark Spencer', 1),
#  ('Jimmy Stone', 1),
#  ('Joanna Williams', 1),
#  ('Nathaniel Camacho', 1),
#  ('Corey Smith', 1),
#  ('James Murphy', 1),
#  ('Stephanie Baker', 2),
#  ('Sarah Rivera DVM', 2),
#  ('William Thomas', 2),
#  ('Adrian Garcia', 2),
#  ('John James', 1),
#  ('Lisa Rodriguez', 1),
#  ('Anthony Sandoval', 1),
#  ('Darren Lewis', 1),
#  ('Becky Hayes', 1),
#  ('Christopher Daniels', 4),
#  ('Jordan Lopez', 1),
#  ('Johnny Nelson', 2),
#  ('Frank Garcia', 1),
#  ('Nicole Miller', 3),
#  ('Katherine Hart', 1),
#  ('Carolyn Pennington', 4),
#  ('James Decker', 1),
#  ('Jenna Rodriguez', 2),
#  ('Pamela Newman', 1),
#  ('Suzanne Compton PhD', 1),
#  ('Blake Noble', 2),
#  ('Maria Whitney', 1),
#  ('Michael Hanson', 1),
#  ('Bailey Scott', 3),
#  ('Jessica Avila', 1),
#  ('Austin Frost', 2),
#  ('April Molina', 3),
#  ('Diane Dixon', 1),
#  ('Lindsay Ramirez', 3),
#  ('Veronica Larsen', 4),
#  ('Robert Wallace', 2),
#  ('Elizabeth Gordon', 3),
#  ('Christopher Figueroa', 2),
#  ('Teresa Martin', 1),
#  ('Mr. Zachary Watson DVM', 3),
#  ('Sarah Barker', 1),
#  ('Alexander Wilson', 1),
#  ('Suzanne Burns', 2),
#  ('Howard Ward', 3),
#  ('Gloria Cunningham', 1),
#  ('Sarah Hicks', 3),
#  ('Susan Robinson', 2),
#  ('Derek Lynch', 1),
#  ('Lisa Fischer', 1),
#  ('Ronald Schroeder', 3),
#  ('Perry Schaefer', 1),
#  ('Jessica Vance', 1),
#  ('Suzanne Phillips', 3),
#  ('Amy Martin', 3),
#  ('Michael Rios', 2),
#  ('Abigail Jones', 1),
#  ('Kelsey Taylor', 3),
#  ('Lauren Rogers', 1),
#  ('Melissa Mckay', 1),
#  ('Ashley Kirk', 1),
#  ('Michaela Burns', 2),
#  ('Lisa Small', 3),
#  ('Ashlee Hunt', 1),
#  ('Spencer Stephens', 1),
#  ('Patrick Miller', 1),
#  ('William Brown', 1),
#  ('Lisa Glover', 1),
#  ('Amanda Thompson', 2),
#  ('Amanda White', 2),
#  ('Amy Dalton', 1),
#  ('Tiffany Gates', 1),
#  ('Chad Fernandez', 2),
#  ('Matthew Baldwin', 1),
#  ('Michael Frost', 1),
#  ('Sean Hill', 2),
#  ('Sandra Robinson', 1),
#  ('David Kelley', 2),
#  ('Courtney Baird', 2),
#  ('Frederick Hoffman', 1),
#  ('Chase Leblanc', 1),
#  ('Nicholas Murphy', 1),
#  ('Anthony Jones', 2),
#  ('James Romero', 3),
#  ('Linda Shah', 2),
#  ('Matthew Burns', 1),
#  ('Briana Robles', 2),
#  ('Kara Zimmerman', 1),
#  ('Timothy Rogers', 1),
#  ('Theresa Navarro', 1),
#  ('Douglas Myers', 1),
#  ('Jonathan Cline', 4),
#  ('Anthony Jacobs', 2),
#  ('Melissa Rose', 1),
#  ('Leah Reyes', 1),
#  ('Rebecca Jacobs', 1),
#  ('James Salas', 1),
#  ('Ashley Little', 1),
#  ('David Maldonado', 1),
#  ('Jacob Cummings', 1),
#  ('Autumn Johnson', 3),
#  ('Tonya Woods', 1),
#  ('Rachel Perry', 1),
#  ('Jocelyn Mcgee', 1),
#  ('John Jordan', 1),
#  ('Andrea Smith', 1),
#  ('Joseph Burton', 1),
#  ('Amy Barrett', 1),
#  ('Katie Miller', 3),
#  ('Billy Byrd', 2),
#  ('Rebecca Rose', 2),
#  ('Michael Cox', 2),
#  ('Jason Lee', 2),
#  ('Rebecca Quinn', 1),
#  ('Jessica Horton', 2),
#  ('Jeffery Sims', 2),
#  ('Crystal Martinez', 1),
#  ('Brian Austin', 3),
#  ('William Callahan', 1),
#  ('Amanda Stewart', 1),
#  ('Joseph Nash', 1),
#  ('Timothy Harris', 1),
#  ('Charles Banks', 2),
#  ('Marissa Douglas', 1),
#  ('Juan Peterson', 1),
#  ('Diana Melton', 1),
#  ('Brittany Day', 1),
#  ('Ryan Daugherty', 1),
#  ('Christine Ellis', 1),
#  ('Johnny Leon', 2),
#  ('Sara Griffith', 1),
#  ('Jeanette Carter', 1),
#  ('Christopher Chavez', 2),
#  ('Alan Ayers', 3),
#  ('Sandra Hawkins', 1),
#  ('Stephen Hatfield', 3),
#  ('Christine Larson', 1),
#  ('Bryan Cook', 2),
#  ('Amber Johnson', 3),
#  ('Lori Miller', 1),
#  ('Christian Garza', 1),
#  ('Edward Dougherty', 1),
#  ('Kenneth Holland', 1),
#  ('Jessica Montoya', 2),
#  ('Anne Curtis', 1),
#  ('Megan Meyer MD', 1),
#  ('Veronica Gonzalez', 1),
#  ('Joseph Diaz', 1),
#  ('Crystal Carlson DVM', 1),
#  ('Tyler Kelly', 1),
#  ('April Pearson', 2),
#  ('Sherri Hardin', 2),
#  ('Tina Griffin', 4),
#  ('Anthony Mccoy', 2),
#  ('Laurie Mccarthy', 2),
#  ('Elizabeth Doyle', 2),
#  ('Carla Barrera', 4),
#  ('Matthew Martinez', 2),
#  ('Lindsey Young', 2),
#  ('Erica Schultz', 2),
#  ('Patrick Bass', 3),
#  ('Richard Nixon', 1),
#  ('Mrs. Lisa Preston', 2),
#  ('Kathy Duran', 1),
#  ('Micheal Barker', 4),
#  ('Sergio Lee', 1),
#  ('Michael Watkins', 1),
#  ('Mr. John Andrews', 1),
#  ('Danielle Silva', 4),
#  ('Mario Howard', 2),
#  ('Randy Miller', 2),
#  ('Rebecca Mitchell', 2),
#  ('Cynthia Collins', 1),
#  ('Jeremy Powell', 3),
#  ('Robert Cantu', 1),
#  ('Emily Thomas', 1),
#  ('Stephen Hudson', 1),
#  ('Donna Kim', 2),
#  ('Mary Gutierrez', 1),
#  ('Michael Gibbs', 3),
#  ('William Flores', 1),
#  ('Ronald Wyatt', 1),
#  ('Brian Oneal', 2),
#  ('Benjamin Ayers', 1),
#  ('James Reyes', 1),
#  ('Patrick Ritter', 2),
#  ('Justin Shaffer', 5),
#  ('Andres Hernandez', 2),
#  ('Alison Cook', 1),
#  ('Anne Rogers', 1),
#  ('Dr. Adam Johnson', 1),
#  ('Adam Sullivan', 2),
#  ('Ryan Allen', 2),
#  ('Deborah Yates', 1),
#  ('Melissa Wright', 2),
#  ('Rachael Miles MD', 1),
#  ('Jeffrey Salinas', 3),
#  ('Cynthia Gibson', 1),
#  ('Christopher Coleman', 2),
#  ('Melissa White', 1),
#  ('Eric Andrews', 2),
#  ('Katherine Adams', 2),
#  ('Michelle Hernandez', 2),
#  ('Morgan Beard', 2),
#  ('Sean Hebert', 1),
#  ('Rodney Smith', 1),
#  ('Austin Brown', 2),
#  ('Mr. Kevin Stewart II', 1),
#  ('Patricia Shepard', 1),
#  ('Jeremy Wright', 3),
#  ('Tiffany Sims', 1),
#  ('Nicholas Castillo', 2),
#  ('Michael Warren', 1),
#  ('Richard Snow', 2),
#  ('Stephanie Martinez', 1),
#  ('Hannah Morales', 2),
#  ('Mark Smith', 2),
#  ('Robin Lawson', 3),
#  ('Tyler Myers', 2),
#  ('David Lawrence', 1),
#  ('Victoria Tucker', 1),
#  ('Sean Goodman', 1),
#  ('Nathan Frank', 1),
#  ('Raymond Hudson', 4),
#  ('James Yang', 1),
#  ('Lisa Terry', 1),
#  ('Nicole Garner', 2),
#  ('Jared Zamora', 2),
#  ('Lori Fuller', 2),
#  ('Ruben Berry', 2),
#  ('Daniel Leon', 2),
#  ('Rachel Pena', 1),
#  ('Nicholas Schmidt', 1),
#  ('Kimberly Pineda', 1),
#  ('Megan Malone', 1),
#  ('Christine Owens', 1),
#  ('Joseph Brooks', 1),
#  ('Desiree Hill', 1),
#  ('Nicholas Doyle', 1),
#  ('Carmen Campbell', 1),
#  ('Elizabeth White MD', 1),
#  ('Justin Kirby', 1),
#  ('John Roth', 1),
#  ('Michael Reid', 1),
#  ('Shannon Graves', 1),
#  ('Candace King', 2),
#  ('Tina Howard', 1),
#  ('Scott Harmon', 2),
#  ('Amy Moore', 1),
#  ('Nicholas Harris', 1),
#  ('Joel Campbell', 1),
#  ('David Reeves', 1),
#  ('Maria Johnson', 1),
#  ('Brian Owens', 2),
#  ('Amy Wilson', 2),
#  ('Daniel Ellis', 2),
#  ('Mark Greene', 1),
#  ('Anthony Mcdonald', 1),
#  ('Michael Carroll', 1),
#  ('Kevin Lane', 1),
#  ('Jonathan Stephens', 3),
#  ('Jennifer Gordon', 1),
#  ('Ronald Hawkins', 1),
#  ('Mary Thomas', 2),
#  ('Sandra Rhodes', 1),
#  ('Laura Richards', 3),
#  ('Christian Warner', 2),
#  ('Tyler Brown', 1),
#  ('Elizabeth Parker', 1),
#  ('Ruth Weiss', 1),
#  ('Kenneth Gardner', 3),
#  ('Ryan Lopez', 1),
#  ('Sheri Brown', 1),
#  ('Tiffany Hernandez', 3),
#  ('Kathryn Franklin', 2),
#  ('Marc Stout II', 2),
#  ('Brian Rodriguez', 1),
#  ('Robyn Johnson', 1),
#  ('Annette Bryan', 1),
#  ('Tiffany Johnson', 1),
#  ('Jessica Rodriguez', 1),
#  ('Kayla Schmitt', 1),
#  ('Denise Gonzales', 1),
#  ('Anthony Fields', 1),
#  ('George Collier', 1),
#  ('Brenda Mcgrath', 2),
#  ('Joshua Booth', 2),
#  ('Michelle Roberts', 1),
#  ('Rebecca Jones', 2),
#  ('Adam Kelly', 3),
#  ('Stephen Todd', 3),
#  ('Sheryl Allen', 2),
#  ('Cynthia Christian', 1),
#  ('Nathan Martinez', 1),
#  ('Thomas Williams', 5),
#  ('Christopher Smith', 1),
#  ('Nicholas Bray MD', 2),
#  ('Robert Williams', 2),
#  ('Timothy Howard', 1),
#  ('Tina Evans', 1),
#  ('Rebecca White', 3),
#  ('Adam Lopez', 2),
#  ('Yolanda Thomas', 3),
#  ('Carmen Wheeler', 2),
#  ('Pamela Murphy', 1),
#  ('Anna Johnson', 2),
#  ('Justin Reed', 1),
#  ('Alice Hernandez', 1),
#  ('Ryan Mathews', 2),
#  ('Rebekah Chambers', 1),
#  ('Alexander David', 1),
#  ('Tina Williams', 2),
#  ('Rachel Moody', 3),
#  ('Olivia Hall', 2),
#  ('Timothy Hicks', 5),
#  ('Raymond Clark', 1),
#  ('Johnny Kennedy', 1),
#  ('Teresa Jones', 1),
#  ('Jeffery Osborne', 2),
#  ('Heather Webster', 2),
#  ('Elizabeth Potts', 2),
#  ('Brett Watts', 1),
#  ('Joseph Harrison', 1),
#  ('Michael Hill', 2),
#  ('Linda Ellis', 2),
#  ('Suzanne Smith', 3),
#  ('Jason Ward', 1),
#  ('Christopher Young', 1),
#  ('Julie Jones', 1),
#  ('Kelly Mcdaniel', 1),
#  ('Lauren Gibson', 2),
#  ('Michael Turner', 1),
#  ('Ross Galloway', 1),
#  ('Jonathan Bryan', 1),
#  ('Steven Davila', 2),
#  ('Crystal Webster', 1),
#  ('Jake Norton', 1),
#  ('Elizabeth Keith', 1),
#  ('Christopher Jones', 1),
#  ('Danny Taylor', 2),
#  ('Jacob Taylor', 1),
#  ('Selena Taylor', 2),
#  ('Stephanie Brock', 2),
#  ('Susan Russell', 2),
#  ('Angela Craig', 1),
#  ('David Stark', 1),
#  ('Donna Parsons', 1),
#  ('Amy Carter', 2),
#  ('Justin Carroll', 2),
#  ('John Summers', 1),
#  ('Kevin Smith', 2),
#  ('Shelby Rocha', 1),
#  ('Heather Turner MD', 1),
#  ('Mary Moore', 2),
#  ('Jacob Allen', 2),
#  ('Kelly Nelson', 2),
#  ('Caroline Nguyen', 1),
#  ('Dr. Jerry Ryan', 1),
#  ('Jesse Hall', 1),
#  ('Scott King', 2),
#  ('Richard Pearson', 3),
#  ('Lisa Walton DDS', 1),
#  ('Vanessa Richards', 2),
#  ('Jill Shepherd', 3),
#  ('Helen Martin', 1),
#  ('Randy Young', 1),
#  ('Darryl Stewart', 1),
#  ('Patrick Anderson', 1),
#  ('David Taylor', 1),
#  ('Dana Taylor', 1),
#  ('Mrs. Linda Burns', 3),
#  ('Mary Martinez', 1),
#  ('Joel Martinez', 2),
#  ('Dr. Nicholas Murray', 1),
#  ('Seth Jones', 1),
#  ('Chad Cortez', 2),
#  ('Michael Poole', 1),
#  ('Scott Hanson', 2),
#  ('Meagan Martin', 1),
#  ('Devon Wells', 1),
#  ('Sandra Carlson', 3),
#  ('Sara Lopez', 1),
#  ('Tammy Ramirez', 1),
#  ('Billy Reynolds', 1),
#  ('Kathryn Mccall', 1),
#  ('William Edwards', 1),
#  ('Sylvia Simmons', 1),
#  ('Ian Wilson', 2),
#  ('Daryl Phillips', 1),
#  ('Nathan Lynn', 1),
#  ('Tamara Carey', 2)]

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
